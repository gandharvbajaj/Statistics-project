# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# #Customer Purchase Behavior Analysis using Descriptive Statistics
# **Contribution: GANDHARV BAJAJ**

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %%
# importing required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#loading data
path = "/content/drive/MyDrive/Superstore Marketing Data - Sheet1.csv"
df = pd.read_csv(path)

# %%
# First 5 rows
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3    ########        0        10  ...                0                 0
# 4    ########        0         6  ...               11                 0
#
# ...

# %%
# last 5 rows
df.tail()
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 2235         1    ########       99       372  ...               47
# 2236         0   1/22/2013       99         5  ...                3
# 2237         0    ########       99       185  ...               15
# 2238         0  11/29/2012       99       267  ...              149
# 2239         2    ########       99       169  ...              188
#
#       MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# ...

# %%
# shape of the dataframe

print(df.shape)
print("Total number of Rows are ",df.shape[0])
print("Total number of columns are ",df.shape[1])
# Out:
# (2240, 22)
# Total number of Rows are  2240
# Total number of columns are  22

# %%
# Information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
# description of the numerical data in the DataFrame
df.describe().T
# Out:
#                       count          mean           std     min       25%  \
# Id                   2240.0   5592.159821   3246.662198     0.0   2828.25
# Year_Birth           2240.0   1968.805804     11.984069  1893.0   1959.00
# Income               2216.0  52247.251354  25173.076661  1730.0  35303.00
# Kidhome              2240.0      0.444196      0.538398     0.0      0.00
# Teenhome             2240.0      0.506250      0.544538     0.0      0.00
# Recency              2240.0     49.109375     28.962453     0.0     24.00
# MntWines             2240.0    303.935714    336.597393     0.0     23.75
# MntFruits            2240.0     26.302232     39.773434     0.0      1.00
# MntMeatProducts      2240.0    166.950000    225.715373     0.0     16.00
# MntFishProducts      2240.0     37.525446     54.628979     0.0      3.00
# MntSweetProducts     2240.0     27.062946     41.280498     0.0      1.00
# MntGoldProds         2240.0     44.021875     52.167439     0.0      9.00
# ...

# %%
# checking total number of dublicate values
df.duplicated().sum()
# Out:
# 0

# %%
#c hecking total number of null values
df.isnull().sum()
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %%
# reating a copy of dataset
new = df.copy()

# %%
# Visualising missing values in dataset
sns.heatmap(new.isnull(),cmap="Greens",)
# Out:
# <Axes: >

# %%
# Droping id column because we dont want to use it for our analysis
new.drop(columns = ['Id'],inplace=True)

# %%
# Average income
avg_income = round(new['Income'].mean(),2)
avg_income
# Out:
# 52247.25

# %%
# finding avg income and  filling the null values with tha average income
avg_income = round(new['Income'].mean(),2)
new['Income'].fillna(avg_income,inplace = True)
new['Income'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %%
#distribution of ages according to birth year

sns.histplot(new['Year_Birth'], bins=40, kde=True)
plt.title ("distribution of ages")
plt.xlabel("Birth year")
plt.ylabel("Number of births")
plt.show()

# %%
# Distribution by marital status
sns.countplot(x=new['Marital_Status'],data=new)
plt.title('Distribution according to Marital status')
plt.show()

# %%
# Distribution by Education
sns.countplot(x=new['Education'],data=new)
plt.title('Distribution according to Education')
plt.show()

# %%
# distribution by income
sns.histplot(new['Income'], bins=80, kde=True)
plt.title ("distribution of Incomes")

plt.show()

# %% [markdown]
# #Outlier detection and handeling

# %%
from scipy import stats
important_columns = ['Income', 'MntFishProducts', 'MntMeatProducts', 'MntFruits', 'MntSweetProducts', 'MntWines', 'MntGoldProds', 'NumDealsPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebPurchases', 'NumWebVisitsMonth', 'Recency']


# Calculating the z-score for each value in the 'important_columns' columns
z_scores = stats.zscore(new[important_columns])

# Define a threshold for outlier identification
threshold = 3

# Identify outliers based on the z-score threshold
outliers = new[important_columns][abs(z_scores) > threshold]

# Print the outliers
print(outliers)
# Out:
#       Income  MntFishProducts  MntMeatProducts  MntFruits  MntSweetProducts  \
# 0        NaN              NaN              NaN        NaN             189.0
# 1        NaN              NaN              NaN        NaN               NaN
# 2        NaN              NaN              NaN        NaN               NaN
# 3        NaN              NaN              NaN        NaN               NaN
# 4        NaN              NaN              NaN        NaN               NaN
# ...      ...              ...              ...        ...               ...
# 2235     NaN              NaN              NaN        NaN               NaN
# 2236     NaN              NaN              NaN        NaN               NaN
# 2237     NaN              NaN              NaN        NaN               NaN
# 2238     NaN              NaN              NaN        NaN             165.0
# 2239     NaN              NaN              NaN        NaN               NaN
#
# ...

# %%
#  creating boxplot for outlier in important column

for column in important_columns:
  sns.boxplot(x=new[column])
  plt.show()

# %%
total_purchases = df[['NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases']].sum(axis=1)
p_purchase = total_purchases.mean() / total_purchases.max()
expected_purchases = total_purchases.mean()

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %%
# Mean of important columns

important_columns = ['Income', 'MntFishProducts', 'MntMeatProducts', 'MntFruits', 'MntSweetProducts', 'MntWines', 'MntGoldProds', 'NumDealsPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebPurchases', 'NumWebVisitsMonth', 'Recency']

new[important_columns].mean()
# Out:
# Income                 52247.251339
# MntFishProducts           37.525446
# MntMeatProducts          166.950000
# MntFruits                 26.302232
# MntSweetProducts          27.062946
# MntWines                 303.935714
# MntGoldProds              44.021875
# NumDealsPurchases          2.325000
# NumCatalogPurchases        2.662054
# NumStorePurchases          5.790179
# NumWebPurchases            4.084821
# NumWebVisitsMonth          5.316518
# Recency                   49.109375
# dtype: float64

# %%
# Median of important columns
new[important_columns].median()
# Out:
# Income                 51741.5
# MntFishProducts           12.0
# MntMeatProducts           67.0
# MntFruits                  8.0
# MntSweetProducts           8.0
# MntWines                 173.5
# MntGoldProds              24.0
# NumDealsPurchases          2.0
# NumCatalogPurchases        2.0
# NumStorePurchases          5.0
# NumWebPurchases            4.0
# NumWebVisitsMonth          6.0
# Recency                   49.0
# dtype: float64

# %%
new[important_columns].mode()
# Out:
#      Income  MntFishProducts  MntMeatProducts  MntFruits  MntSweetProducts  \
# 0  52247.25                0                7          0                 0
#
#    MntWines  MntGoldProds  NumDealsPurchases  NumCatalogPurchases  \
# 0         2             1                  1                    0
#
#    NumStorePurchases  NumWebPurchases  NumWebVisitsMonth  Recency
# 0                  3                2                  7       56

# %%
# Variance of important columns
new[important_columns].var()
# Out:
# Income                 6.268913e+08
# MntFishProducts        2.984325e+03
# MntMeatProducts        5.094743e+04
# MntFruits              1.581926e+03
# MntSweetProducts       1.704080e+03
# MntWines               1.132978e+05
# MntGoldProds           2.721442e+03
# NumDealsPurchases      3.733542e+00
# NumCatalogPurchases    8.544517e+00
# NumStorePurchases      1.056873e+01
# NumWebPurchases        7.721252e+00
# NumWebVisitsMonth      5.888606e+00
# Recency                8.388237e+02
# dtype: float64

# %%
# standard variance  of important columns
new[important_columns].std()
# Out:
# Income                 25037.797168
# MntFishProducts           54.628979
# MntMeatProducts          225.715373
# MntFruits                 39.773434
# MntSweetProducts          41.280498
# MntWines                 336.597393
# MntGoldProds              52.167439
# NumDealsPurchases          1.932238
# NumCatalogPurchases        2.923101
# NumStorePurchases          3.250958
# NumWebPurchases            2.778714
# NumWebVisitsMonth          2.426645
# Recency                   28.962453
# dtype: float64

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %%
# Exploring Relationships
# 1. Analyze the relationship between income and spending on different product categories.

sns.pairplot(data=new, x_vars=['Income'], y_vars=['MntFishProducts', 'MntMeatProducts', 'MntFruits', 'MntSweetProducts', 'MntWines', 'MntGoldProds'], kind='reg')
plt.show()

# %%
# 4. Visualize the customer segments based on their spending habits and other characteristics.
sns.scatterplot(x='Income', y='MntWines', data=new)
plt.show()

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %%
# correlation between important columns
important_columns = new[['Income', 'MntFishProducts', 'MntMeatProducts', 'MntFruits', 'MntSweetProducts', 'MntWines', 'MntGoldProds', 'NumDealsPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebPurchases', 'NumWebVisitsMonth', 'Recency']]


# Create the heatmap

plt.figure(figsize = (10, 8))
sns.heatmap(important_columns.corr(), annot=True)
plt.show()

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %% [markdown]
# * The analysis of customer demographics revealed that the majority of customers are between the ages of 25 and 54, have a graduation degree, and are married.
# * The distribution of income is skewed to the right, with a few customers having very high incomes.
# There are outliers in several important columns, such as income and spending habits.
# * The probability of a customer making a purchase is 50%.

# %% [markdown]
# Recommendations:
#
# * The company should focus its marketing efforts on customers between the ages of 25 and 54, with a graduation degree, and who are married.
# * The company should offer more discounts and promotions to encourage customers to make more purchases.
# * The company should improve its website and online presence to make it easier for customers to make purchases online.
# * The company should track customer behavior and purchase history to identify trends and patterns.
# * If company wants to expand so their business they can launch products around mean income or if possible give dicounts on available products in such a way that the average income slab could be better targeted.
